# %%
import pandas as pd

pd.options.display.max_columns = 60

# %%
dash_df = pd.read_csv('../data/processed/redfin_housing_data.csv.gz')

# %%
dash_df.shape
# Out:
# (8160314, 58)

# %%
dash_df.head()
# Out:
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2016-06-01  2016-08-31               90    zip code               2
# 1   2022-12-01  2023-02-28               90    zip code               2
# 2   2023-02-01  2023-04-30               90    zip code               2
# 3   2023-07-01  2023-09-30               90    zip code               2
# 4   2017-03-01  2017-05-31               90    zip code               2
#
#    table_id is_seasonally_adjusted   region  city          state  ...  \
# 0      5140                      f  14425.0   NaN       New York  ...
# 1     35093                      f  81005.0   NaN       Colorado  ...
# 2       344                      f   1355.0   NaN  Massachusetts  ...
# 3      9641                      f  24176.0   NaN       Virginia  ...
# 4     41207                      f  98663.0   NaN     Washington  ...
#
#   sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# ...

# %%
dash_df.describe()
# Out:
#        period_duration  region_type_id      table_id        region  city  \
# count        8160314.0       8160314.0  8.160314e+06  24223.000000   0.0
# mean              90.0             2.0  2.031487e+04  48579.938117   NaN
# std                0.0             0.0  1.284916e+04  28813.151760   NaN
# min               90.0             2.0  1.000000e+00    501.000000   NaN
# 25%               90.0             2.0  8.513000e+03  23063.500000   NaN
# 50%               90.0             2.0  1.940400e+04  46940.000000   NaN
# 75%               90.0             2.0  3.254500e+04  73523.500000   NaN
# max               90.0             2.0  4.208800e+04  99901.000000   NaN
#
#        property_type_id  median_sale_price  median_sale_price_mom  \
# count      8.160314e+06       8.145097e+06           7.771659e+06
# mean       3.777361e+00       3.035284e+05           2.053298e-01
# std        4.271055e+00       9.433931e+05           1.477577e+02
# ...

# %%
dash_df.loc[dash_df.period_end >= '2024-02-29'].shape
# Out:
# (231418, 58)

# %%
dash_df1 = dash_df.loc[dash_df.period_end >= '2024-02-29']
dash_df1.sort_values(['region','property_type','period_end'], inplace=True)
# Out:
# C:\Users\wheat\OneDrive\Dev\project_zipliner\zipliner\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dash_df1
# Out:
#         period_begin  period_end  period_duration region_type  region_type_id  \
# 475       2023-12-01  2024-02-29               90    zip code               2
# 3356      2024-03-01  2024-05-31               90    zip code               2
# 1199511   2024-03-01  2024-05-31               90    zip code               2
# 1259648   2023-12-01  2024-02-29               90    zip code               2
# 1558956   2024-03-01  2024-05-31               90    zip code               2
# ...              ...         ...              ...         ...             ...
# 8156778   2024-03-01  2024-05-31               90    zip code               2
# 8156819   2024-03-01  2024-05-31               90    zip code               2
# 8156845   2024-03-01  2024-05-31               90    zip code               2
# 8157900   2024-03-01  2024-05-31               90    zip code               2
# 8158664   2024-03-01  2024-05-31               90    zip code               2
#
# ...

# %%
df = dash_df1.groupby(['region','property_type']).last()
df
# Out:
#                                   period_begin  period_end  period_duration  \
# region  property_type
# 1301.0  Townhouse                   2023-12-01  2024-02-29               90
# 1337.0  Single Family Residential   2024-03-01  2024-05-31               90
# 1350.0  All Residential             2024-03-01  2024-05-31               90
# 1607.0  Single Family Residential   2023-12-01  2024-02-29               90
# 1752.0  Condo/Co-op                 2024-03-01  2024-05-31               90
# ...                                        ...         ...              ...
# 99022.0 All Residential             2024-03-01  2024-05-31               90
# 99345.0 All Residential             2024-03-01  2024-05-31               90
# 99502.0 Multi-Family (2-4 Unit)     2024-02-01  2024-04-30               90
# 99667.0 All Residential             2024-01-01  2024-03-31               90
# 99901.0 Single Family Residential   2023-12-01  2024-02-29               90
#
# ...

# %%
df = dash_df.groupby(['region','property_type']).last()
df['last_update_year'] = df.period_end.apply(lambda x: int(str(x)[:4]))
df1 = df.loc[df.last_update_year == 2024]
df1.head()
# Out:
#                                  period_begin  period_end  period_duration  \
# region property_type
# 1301.0 Townhouse                   2023-12-01  2024-02-29               90
# 1337.0 Single Family Residential   2024-03-01  2024-05-31               90
# 1350.0 All Residential             2024-03-01  2024-05-31               90
# 1607.0 Single Family Residential   2023-12-01  2024-02-29               90
# 1752.0 Condo/Co-op                 2024-03-01  2024-05-31               90
#
#                                  region_type  region_type_id  table_id  \
# region property_type
# 1301.0 Townhouse                    zip code               2       326
# 1337.0 Single Family Residential    zip code               2       330
# 1350.0 All Residential              zip code               2       341
# 1607.0 Single Family Residential    zip code               2       444
# 1752.0 Condo/Co-op                  zip code               2       475
#
# ...

# %%
# Out:
# (231418, 58)

# %%
df.head(50)
# Out:
#                                  period_begin  period_end  period_duration  \
# region property_type
# 501.0  Single Family Residential   2023-10-01  2023-12-31               90
# 1001.0 All Residential             2015-04-01  2015-06-30               90
# 1002.0 Condo/Co-op                 2018-04-01  2018-06-30               90
# 1003.0 Multi-Family (2-4 Unit)     2013-12-01  2014-02-28               90
# 1004.0 Single Family Residential   2016-05-01  2016-07-31               90
# 1005.0 Single Family Residential   2023-07-01  2023-09-30               90
# 1007.0 Single Family Residential   2017-09-01  2017-11-30               90
# 1008.0 Single Family Residential   2022-01-01  2022-03-31               90
# 1009.0 All Residential             2019-04-01  2019-06-30               90
# 1010.0 Single Family Residential   2021-07-01  2021-09-30               90
# 1011.0 All Residential             2014-12-01  2015-02-28               90
# ...
